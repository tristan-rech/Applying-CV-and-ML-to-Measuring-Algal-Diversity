# %% [markdown]
# ## Import

# %%
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import glob
import shutil
from pathlib import Path
import seaborn as sns
import numpy as np
import math

# %% [markdown]
# #### Example Preprocessing of whole "ET22-05" experiment and every subdirectory

# %% [markdown]
# ### Segment Each Image from FlowCam Image Sheets

# %%
def segment_image(top_input_dir, top_output_dir, min_area=100):
    """
    Processes .tif files (except binary) in the input directory and its subdirectories, 
    extracting cell images from each and saving them in sorted order in the output directory.
    
    Parameters:
    - top_input_dir: The top-level directory containing the subdirectories with .tif files to process.
    - top_output_dir: The top-level directory where the 'split' directories will be created for output.
    - min_area: The minimum area threshold for a contour to be considered a valid rectangle.
    
    """
    # Ensure the top-level output directory exists
    top_output_dir = os.path.join(top_output_dir, 'ET22-05-split')
    if not os.path.isdir(top_output_dir):
        os.makedirs(top_output_dir)

    for subdir, dirs, files in os.walk(top_input_dir):
        for file in files:
            if file.endswith('.tif') and 'bin' not in file:
                file_path = os.path.join(subdir, file)
                print(f"Processing {file_path}...")
                
                # Compute a relative path to create a parallel structure in the output
                relative_path = os.path.relpath(subdir, top_input_dir)
                output_dir = os.path.join(top_output_dir, relative_path)
                
                # Ensure the output directory exists
                if not os.path.isdir(output_dir):
                    os.makedirs(output_dir)
                
                # Read the image
                image = cv2.imread(file_path)
                
                # Convert the image to grayscale and apply a binary threshold
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                _, binary_threshold = cv2.threshold(gray_image, 1, 255, cv2.THRESH_BINARY)
                
                # Find contours
                contours, _ = cv2.findContours(binary_threshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                valid_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]
                sorted_contours = sorted(valid_contours, key=lambda cnt: (cv2.boundingRect(cnt)[1], cv2.boundingRect(cnt)[0]))
                
                # Extract and save rectangles
                for i, contour in enumerate(sorted_contours):
                    x, y, w, h = cv2.boundingRect(contour)
                    sorted_extracted_image = image[y:y+h, x:x+w]
                    file_name = f'{Path(file).stem}_{i+1:06}.png'  # Use the original file name with a counter
                    file_save_path = os.path.join(output_dir, file_name)
                    cv2.imwrite(file_save_path, sorted_extracted_image)

                print(f"Finished processing {file_path}")

# Example usage:
top_input_dir = 'data/ET22-05'
top_output_dir = 'data'
segment_image(top_input_dir, top_output_dir)
# Out:
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000001.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000001.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000002.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000002.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000003.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000003.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000004.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000004.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000005.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000005.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000006.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000006.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000007.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000007.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000008.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000008.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000009.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000009.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000010.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000010.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000011.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000011.tif
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000012.tif...
# Finished processing data/ET22-05\Control\ET-1 C3\ET-1 C3_000012.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000001.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000001.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000002.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000002.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000003.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000003.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000004.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000004.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000005.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000005.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000006.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000006.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000007.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000007.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000008.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000008.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000009.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000009.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000010.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000010.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000011.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000011.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000012.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000012.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000013.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000013.tif
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000014.tif...
# Finished processing data/ET22-05\Control\ET-1 C4\ET-1 C4_000014.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000001.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000001.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000002.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000002.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000003.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000003.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000004.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000004.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000005.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000005.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000006.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000006.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000007.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000007.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000008.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000008.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000009.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000009.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000010.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000010.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000011.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000011.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000012.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000012.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000013.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000013.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000014.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000014.tif
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000015.tif...
# Finished processing data/ET22-05\Control\ET-1 Final\ET-1 Final_000015.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000001.tif...
# Finished processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000001.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000002.tif...
# Finished processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000002.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000003.tif...
# Finished processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000003.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000004.tif...
# Finished processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000004.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000005.tif...
# Finished processing data/ET22-05\Control\ET-2 C3\ET-2 C3_000005.tif
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3_
tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000005.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000006.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000007.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000008.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000008.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000009.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000009.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000010.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000010.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000011.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000011.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000012.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000012.tif
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000013.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4_000013.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000001.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000002.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000003.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000004.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000004.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000005.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000006.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000007.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000008.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000008.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000009.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000009.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000010.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000010.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000011.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000011.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000012.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000012.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000013.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000013.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000014.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000014.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000015.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000015.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000016.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000016.tif
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000017.tif...
# Finished processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final_000017.tif
# Processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000001.tif
# Processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000002.tif
# Processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1_000003.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000001.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000002.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000003.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000004.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000004.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000005.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000006.tif
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2_000007.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000001.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000002.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000003.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000004.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000004.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000005.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000006.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000007.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000008.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000008.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000009.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000009.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000010.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000010.tif
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000011.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3_000011.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000001.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000002.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000003.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000004.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000004.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000005.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000006.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000007.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000008.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000008.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000009.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000009.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000010.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000010.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000011.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000011.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000012.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000012.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000013.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000013.tif
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000014.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4_000014.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000001.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000001.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000002.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000002.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000003.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000003.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000004.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000004.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000005.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000005.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000006.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000006.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000007.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000007.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000008.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000008.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000009.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000009.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000010.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000010.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000011.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000011.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000012.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000012.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000013.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000013.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000014.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000014.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000015.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000015.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000016.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000016.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000017.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000017.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000018.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000018.tif
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000019.tif...
# Finished processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final_000019.tif

# %% [markdown]
# ### Convert .lst to a Pandas DF in Each New Segmented Image Directory

# %%
def process_lst_files(top_input_dir, top_output_dir):
    """
    Processes .lst files in the input directory and its subdirectories,
    reading each .lst file into a pandas DataFrame and saving it in the
    corresponding mirrored directory structure under the specified top-level output directory.
    
    Parameters:
    - top_input_dir: The top-level directory containing the subdirectories with .lst files.
    - top_output_dir: The top-level directory where the processed .lst files will be saved as DataFrames.
    """
    column_names = [
        'id', 'image_x', 'image_y', 'image_w', 'image_h', 'src_x', 'src_y', 'src_image',
        'cal_image', 'ppc', 'camera', 'cal_const', 'fringe_size', 'sphere_count',
        'raw_sphere_volume', 'raw_sphere_complement', 'raw_sphere_unknown', 'raw_area',
        'raw_feret_max', 'raw_feret_min', 'raw_feret_mean', 'raw_perimeter',
        'raw_convex_perimeter', 'raw_legendre_major', 'raw_legendre_minor', 'abd_area',
        'abd_diameter', 'length', 'width', 'esd_diameter', 'fd_diameter', 'perimeter',
        'convex_perimeter', 'intensity', 'sigma_intensity', 'sum_intensity', 'compactness',
        'elongation', 'roughness', 'edge_gradient', 'elapsed_time', 'circle_fit',
        'symmetry', 'circularity_hu', 'intensity_calimage', 'raw_convex_hull_area',
        'raw_filled_area', 'filled_area', 'feret_max_angle', 'feret_min_angle',
        'avg_red', 'avg_green', 'avg_blue', 'timestamp', 'collage_file', 'image_id'
    ]
    skip_rows = 58

    for subdir, dirs, files in os.walk(top_input_dir):
        for file in files:
            if file.endswith('.lst'):
                file_path = os.path.join(subdir, file)
                print(f"Processing {file_path}...")

                df = pd.read_csv(file_path, delimiter='|', skiprows=skip_rows, header=None, names=column_names)

                # Compute the relative path for the output
                relative_path = os.path.relpath(subdir, top_input_dir)
                output_dir = os.path.join(top_output_dir, relative_path)

                # Ensure the output directory exists
                if not os.path.isdir(output_dir):
                    os.makedirs(output_dir)

                # Define the output file path
                output_file_path = os.path.join(output_dir, Path(file).stem + '_df.csv')

                # Save the DataFrame
                df.to_csv(output_file_path, index=False)
                print(f"Saved DataFrame to {output_file_path}")

top_input_dir = 'data/ET22-05'
top_output_dir = 'data/ET22-05-split'
process_lst_files(top_input_dir, top_output_dir)
# Out:
# Processing data/ET22-05\Control\ET-1 C3\ET-1 C3.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-1 C3\ET-1 C3_df.csv
# Processing data/ET22-05\Control\ET-1 C4\ET-1 C4.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-1 C4\ET-1 C4_df.csv
# Processing data/ET22-05\Control\ET-1 Final\ET-1 Final.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-1 Final\ET-1 Final_df.csv
# Processing data/ET22-05\Control\ET-2 C3\ET-2 C3.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-2 C3\ET-2 C3_df.csv
# Processing data/ET22-05\Control\ET-2 C4\ET-2 C4.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-2 C4\ET-2 C4_df.csv
# Processing data/ET22-05\Control\ET-2 Final\ET-2 Final.lst...
# Saved DataFrame to data/ET22-05-split\Control\ET-2 Final\ET-2 Final_df.csv
# Processing data/ET22-05\ET-B\ET-B1 C1\ET-B1 In.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B1 C1\ET-B1 In_df.csv
# Processing data/ET22-05\ET-B\ET-B1 C2\ET-B1 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B1 C2\ET-B1 C2_df.csv
# Processing data/ET22-05\ET-B\ET-B1 C3\ET-B1 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B1 C3\ET-B1 C3_df.csv
# Processing data/ET22-05\ET-B\ET-B1 C4\ET-B1 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B1 C4\ET-B1 C4_df.csv
# Processing data/ET22-05\ET-B\ET-B1 Final\ET-B1 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B1 Final\ET-B1 Final_df.csv
# Processing data/ET22-05\ET-B\ET-B2 C1\ET-B2 In.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B2 C1\ET-B2 In_df.csv
# Processing data/ET22-05\ET-B\ET-B2 C2\ET-B2 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B2 C2\ET-B2 C2_df.csv
# Processing data/ET22-05\ET-B\ET-B2 C3\ET-B2 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B2 C3\ET-B2 C3_df.csv
# Processing data/ET22-05\ET-B\ET-B2 C4\ET-B2 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B2 C4\ET-B2 C4_df.csv
# Processing data/ET22-05\ET-B\ET-B2 Final\ET-B2 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-B\ET-B2 Final\ET-B2 Final_df.csv
# Processing data/ET22-05\ET-BF\ET-BF1 C1\ET-BF1 C1.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF1 C1\ET-BF1 C1_df.csv
# Processing data/ET22-05\ET-BF\ET-BF1 C2\ET-BF1 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF1 C2\ET-BF1 C2_df.csv
# Processing data/ET22-05\ET-BF\ET-BF1 C3\ET-BF1 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF1 C3\ET-BF1 C3_df.csv
# Processing data/ET22-05\ET-BF\ET-BF1 C4\ET-BF1 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF1 C4\ET-BF1 C4_df.csv
# Processing data/ET22-05\ET-BF\ET-BF1 Final\ET-BF1 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF1 Final\ET-BF1 Final_df.csv
# Processing data/ET22-05\ET-BF\ET-BF2 C1\ET-BF2 C1.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF2 C1\ET-BF2 C1_df.csv
# Processing data/ET22-05\ET-BF\ET-BF2 C2\ET-BF2 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF2 C2\ET-BF2 C2_df.csv
# Processing data/ET22-05\ET-BF\ET-BF2 C3\ET-BF2 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF2 C3\ET-BF2 C3_df.csv
# Processing data/ET22-05\ET-BF\ET-BF2 C4\ET-BF2 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF2 C4\ET-BF2 C4_df.csv
# Processing data/ET22-05\ET-BF\ET-BF2 Final\ET-BF2 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-BF\ET-BF2 Final\ET-BF2 Final_df.csv
# Processing data/ET22-05\ET-F\ET-F1 C1\ET-F1 Initial.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F1 C1\ET-F1 Initial_df.csv
# Processing data/ET22-05\ET-F\ET-F1 C2\ET-F1 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F1 C2\ET-F1 C2_df.csv
# Processing data/ET22-05\ET-F\ET-F1 C3\ET-F1 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F1 C3\ET-F1 C3_df.csv
# Processing data/ET22-05\ET-F\ET-F1 C4\ET-F1 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F1 C4\ET-F1 C4_df.csv
# Processing data/ET22-05\ET-F\ET-F1 Final\ET-F1 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F1 Final\ET-F1 Final_df.csv
# Processing data/ET22-05\ET-F\ET-F2 C1\ET-F2 C1.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F2 C1\ET-F2 C1_df.csv
# Processing data/ET22-05\ET-F\ET-F2 C2\ET-F2 C2.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F2 C2\ET-F2 C2_df.csv
# Processing data/ET22-05\ET-F\ET-F2 C3\ET-F2 C3.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F2 C3\ET-F2 C3_df.csv
# Processing data/ET22-05\ET-F\ET-F2 C4\ET-F2 C4.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F2 C4\ET-F2 C4_df.csv
# Processing data/ET22-05\ET-F\ET-F2 Final\ET-F2 Final.lst...
# Saved DataFrame to data/ET22-05-split\ET-F\ET-F2 Final\ET-F2 Final_df.csv

# %% [markdown]
# ### Filter Empty

# %%
def process_images(top_directory_path):
    """
    Goes through every subdirectory of a given directory, processes all PNG images,
    and moves images considered 'empty' to a 'filtered/empty' subdirectory,
    leaving 'cell' images in their original location.
    """
    # Walk through all subdirectories in the given top directory
    for subdir in Path(top_directory_path).rglob('*'):
        # Skip processing for any "filtered" directories to prevent re-processing
        if 'filtered' in subdir.parts:
            continue

        # Define the output directory for 'empty' images
        empty_dir = subdir / 'filtered' / 'empty'

        # List all PNG images in the current directory
        png_images = list(subdir.glob('*.png'))

        for image_path in png_images:
            # Load the image
            image = cv2.imread(str(image_path), cv2.IMREAD_COLOR)
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Perform edge detection
            edges = cv2.Canny(gray, 100, 200)

            # Determine if edges are present using a simple thresholding approach
            edge_presence = np.mean(edges) > 0  # Thresholding condition

            # Move images to the 'empty' directory if they are deemed 'empty'
            if not edge_presence:
                # Ensure the output directory exists
                empty_dir.mkdir(parents=True, exist_ok=True)
                target_path = empty_dir / image_path.name
                shutil.move(str(image_path), target_path)

top_input_dir = 'data/ET22-05-split'
process_images(top_input_dir)
#25

# %% [markdown]
# ### Filter Partial

# %%
import cv2
import numpy as np
import os
from pathlib import Path

def preprocess_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    return image

def has_significant_edge_near_border(image, border_size=5, edge_threshold=50):
    # Apply edge detection
    edges = cv2.Canny(image, 100, 200)

    # Define border regions (top, bottom, left, right)
    top_border = edges[:border_size, :]
    bottom_border = edges[-border_size:, :]
    left_border = edges[:, :border_size]
    right_border = edges[:, -border_size:]

    # Calculate the sum of edges in the border regions
    border_edge_sum = np.sum(top_border) + np.sum(bottom_border) + np.sum(left_border) + np.sum(right_border)

    # Determine if there is a significant edge near the border
    return border_edge_sum > edge_threshold

def process_directory_for_partial_cells(top_directory_path):
    """
    Processes images in all subdirectories of a given top directory (excluding any "filtered" directories),
    to find partial cell images based on edge detection near borders, moving identified images to a "filtered/partial"
    subdirectory.
    """
    # Walk through all subdirectories in the given top directory
    for subdir in Path(top_directory_path).rglob('*'):
        # Skip processing for any "filtered" directories to prevent re-processing
        if 'filtered' in subdir.parts:
            continue

        # Define the output directory for 'partial' images
        partial_dir = subdir / 'filtered' / 'partial'

        # List all PNG images in the current directory
        png_images = list(subdir.glob('*.png'))

        for image_path in png_images:
            image = preprocess_image(str(image_path))
            if has_significant_edge_near_border(image):
                # Ensure the output directory exists
                partial_dir.mkdir(parents=True, exist_ok=True)
                target_path = partial_dir / image_path.name
                os.rename(str(image_path), target_path)  # Move identified partial cell images

top_directory_path = 'data/ET22-05-split'  # Adjust this to your top-level directory path
process_directory_for_partial_cells(top_directory_path)
#15

# %% [markdown]
# ### Done
# Each directory is filtered of blurred ("empty") and partial cell images. Ready for processing.
